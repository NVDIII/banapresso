# %%
import chromedriver_autoinstaller
import time
from selenium import webdriver
from urllib.request import Request, urlopen
from pymongo import MongoClient

# %%
driver = webdriver.Chrome()
url = 'https://banapresso.com/store'
driver.get(url)

# %%
def getInfo(num):
                 
    name_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{num}]/a/span/i'
    name = driver.find_element('xpath', name_xpath).text
                        
    address_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{num}]/a/span/span'
    address = driver.find_element('xpath', address_xpath).text

    image_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[2]/ul/li[{num}]/a/div/img'
    image_url = driver.find_element('xpath', image_xpath).get_attribute('src')
    file_type = image_url.split('/')[-1].split('.')[-1]
    image_byte = Request(image_url,headers={'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)'})
    f = open(f'이미지/{name}.{file_type}','wb')
    f.write(urlopen(image_byte).read()) 
    f.close()

    # db연결
    url = 'mongodb+srv://wjdgms1004:9pnZGdk1hSaLyFGS@cluster0.maamhu3.mongodb.net/?retryWrites=true&w=majority'
    client = MongoClient(url)
    database = client['banapress']
    collection = database['information']

    # db저장
    user_insert = {'name': name, 'address': address, 'image': f'{name}.{file_type}'}
    result = collection.insert_one(user_insert)
    print(f'입력된 데이터 id: {result.inserted_id}' )

# %%
for j in range(3):
    if j == 2:
        for k in range(2, 5):
            if k == 4:
                for m in range(1, 3):
                    getInfo(m)
                break       
            for i in range(1, 11):
                getInfo(i)

            next_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[{k}]/a'
            driver.find_element('xpath', next_xpath).click()
    else:
        for k in range(2, 7):
            for i in range(1, 11):
                getInfo(i)

            if k == 6:
                clickBt_xpath = '/html/body/div/div/div/div/article/article/div/div[1]/div[3]/span[2]/a'
                driver.find_element('xpath', clickBt_xpath).click()
    
                break
                
            next_xpath = f'/html/body/div/div/div/div/article/article/div/div[1]/div[3]/ul/li[{k}]/a'
            driver.find_element('xpath', next_xpath).click()
# Out:
# 입력된 데이터 id: 6564294af39caef13ec7669a
# 입력된 데이터 id: 6564294af39caef13ec7669c
# 입력된 데이터 id: 6564294af39caef13ec7669e
# 입력된 데이터 id: 6564294bf39caef13ec766a0
# 입력된 데이터 id: 6564294bf39caef13ec766a2
# 입력된 데이터 id: 6564294bf39caef13ec766a4
# 입력된 데이터 id: 6564294cf39caef13ec766a6
# 입력된 데이터 id: 6564294cf39caef13ec766a8
# 입력된 데이터 id: 6564294cf39caef13ec766aa
# 입력된 데이터 id: 6564294cf39caef13ec766ac
# 입력된 데이터 id: 6564294df39caef13ec766ae
# 입력된 데이터 id: 6564294df39caef13ec766b0
# 입력된 데이터 id: 6564294ef39caef13ec766b2
# 입력된 데이터 id: 6564294ef39caef13ec766b4
# 입력된 데이터 id: 6564294ef39caef13ec766b6
# 입력된 데이터 id: 6564294ff39caef13ec766b8
# 입력된 데이터 id: 6564294ff39caef13ec766ba
# 입력된 데이터 id: 6564294ff39caef13ec766bc
# 입력된 데이터 id: 65642950f39caef13ec766be
# 입력된 데이터 id: 65642950f39caef13ec766c0
# 입력된 데이터 id: 65642950f39caef13ec766c2
# 입력된 데이터 id: 65642951f39caef13ec766c4
# 입력된 데이터 id: 65642952f39caef13ec766c6
# 입력된 데이터 id: 65642952f39caef13ec766c8
# 입력된 데이터 id: 65642953f39caef13ec766ca
# 입력된 데이터 id: 65642953f39caef13ec766cc
# 입력된 데이터 id: 65642953f39caef13ec766ce
# 입력된 데이터 id: 65642954f39caef13ec766d0
# 입력된 데이터 id: 65642955f39caef13ec766d2
# 입력된 데이터 id: 65642955f39caef13ec766d4
# 입력된 데이터 id: 65642955f39caef13ec766d6
# 입력된 데이터 id: 65642956f39caef13ec766d8
# 입력된 데이터 id: 65642956f39caef13ec766da
# 입력된 데이터 id: 65642956f39caef13ec766dc
# 입력된 데이터 id: 65642957f39caef13ec766de
# 입력된 데이터 id: 65642957f39caef13ec766e0
# 입력된 데이터 id: 65642957f39caef13ec766e2
# 입력된 데이터 id: 65642958f39caef13ec766e4
# 입력된 데이터 id: 65642958f39caef13ec766e6
# 입력된 데이터 id: 65642958f39caef13ec766e8
# 입력된 데이터 id: 6564295af39caef13ec766ea
# 입력된 데이터 id: 6564295bf39caef13ec766ec
# 입력된 데이터 id: 6564295bf39caef13ec766ee
# 입력된 데이터 id: 6564295bf39caef13ec766f0
# 입력된 데이터 id: 6564295cf39caef13ec766f2
# 입력된 데이터 id: 6564295cf39caef13ec766f4
# 입력된 데이터 id: 6564295cf39caef13ec766f6
# 입력된 데이터 id: 6564295df39caef13ec766f8
# 입력된 데이터 id: 6564295df39caef13ec766fa
# 입력된 데이터 id: 6564295df39caef13ec766fc
# 입력된 데이터 id: 6564295ef39caef13ec766fe
# 입력된 데이터 id: 6564295ef39caef13ec76700
# 입력된 데이터 id: 6564295ff39caef13ec76702
# 입력된 데이터 id: 6564295ff39caef13ec76704
# 입력된 데이터 id: 65642960f39caef13ec76706
# 입력된 데이터 id: 65642961f39caef13ec76708
# 입력된 데이터 id: 65642961f39caef13ec7670a
# 입력된 데이터 id: 65642962f39caef13ec7670c
# 입력된 데이터 id: 65642962f39caef13ec7670e
# 입력된 데이터 id: 65642962f39caef13ec76710
# 입력된 데이터 id: 65642963f39caef13ec76712
# 입력된 데이터 id: 65642963f39caef13ec76714
# 입력된 데이터 id: 65642963f39caef13ec76716
# 입력된 데이터 id: 65642964f39caef13ec76718
# 입력된 데이터 id: 65642964f39caef13ec7671a
# 입력된 데이터 id: 65642964f39caef13ec7671c
# 입력된 데이터 id: 65642965f39caef13ec7671e
# 입력된 데이터 id: 65642965f39caef13ec76720
# 입력된 데이터 id: 65642965f39caef13ec76722
# 입력된 데이터 id: 65642965f39caef13ec76724
# 입력된 데이터 id: 65642968f39caef13ec76726
# 입력된 데이터 id: 65642968f39caef13ec76728
# 입력된 데이터 id: 65642969f39caef13ec7672a
# 입력된 데이터 id: 65642969f39caef13ec7672c
# 입력된 데이터 id: 6564296af39caef13ec7672e
# 입력된 데이터 id: 6564296af39caef13ec76730
# 입력된 데이터 id: 6564296bf39caef13ec76732
# 입력된 데이터 id: 6564296bf39caef13ec76734
# 입력된 데이터 id: 6564296bf39caef13ec76736
# 입력된 데이터 id: 6564296cf39caef13ec76738
# 입력된 데이터 id: 6564296cf39caef13ec7673a
# 입력된 데이터 id: 6564296df39caef13ec7673c
# 입력된 데이터 id: 6564296df39caef13ec7673e
# 입력된 데이터 id: 6564296ef39caef13ec76740
# 입력된 데이터 id: 6564296ef39caef13ec76742
# 입력된 데이터 id: 6564296ff39caef13ec76744
# 입력된 데이터 id: 6564296ff39caef13ec76746
# 입력된 데이터 id: 6564296ff39caef13ec76748
# 입력된 데이터 id: 65642970f39caef13ec7674a
# 입력된 데이터 id: 65642970f39caef13ec7674c
# 입력된 데이터 id: 65642970f39caef13ec7674e
# 입력된 데이터 id: 65642971f39caef13ec76750
# 입력된 데이터 id: 65642971f39caef13ec76752
# 입력된 데이터 id: 65642972f39caef13ec76754
# 입력된 데이터 id: 65642972f39caef13ec76756
# 입력된 데이터 id: 65642972f39caef13ec76758
# 입력된 데이터 id: 65642973f39caef13ec7675a
# 입력된 데이터 id: 65642973f39caef13ec7675c
# 입력된 데이터 id: 65642974f39caef13ec7675e
# 입력된 데이터 id: 65642974f39caef13ec76760
# 입력된 데이터 id: 65642975f39caef13ec76762
# 입력된 데이터 id: 65642975f39caef13ec76764
# 입력된 데이터 id: 65642976f39caef13ec76766
# 입력된 데이터 id: 65642976f39caef13ec76768
# 입력된 데이터 id: 65642976f39caef13ec7676a
# 입력된 데이터 id: 65642977f39caef13ec7676c
# 입력된 데이터 id: 65642977f39caef13ec7676e
# 입력된 데이터 id: 65642978f39caef13ec76770
# 입력된 데이터 id: 65642978f39caef13ec76772
# 입력된 데이터 id: 65642979f39caef13ec76774
# 입력된 데이터 id: 65642979f39caef13ec76776
# 입력된 데이터 id: 65642979f39caef13ec76778
# 입력된 데이터 id: 6564297af39caef13ec7677a
# 입력된 데이터 id: 6564297af39caef13ec7677c
# 입력된 데이터 id: 6564297af39caef13ec7677e
# 입력된 데이터 id: 6564297bf39caef13ec76780
# 입력된 데이터 id: 6564297bf39caef13ec76782
# 입력된 데이터 id: 6564297bf39caef13ec76784
# 입력된 데이터 id: 6564297cf39caef13ec76786
# 입력된 데이터 id: 6564297cf39caef13ec76788
# 입력된 데이터 id: 6564297df39caef13ec7678a
# 입력된 데이터 id: 6564297df39caef13ec7678c
